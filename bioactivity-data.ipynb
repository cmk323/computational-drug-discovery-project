# %% [markdown]
# # Bioactivity data mining for drug discovery using ChEMBL

# %% [markdown]
# Install the ChEMBL web service package to retrieve bioactivity data from ChEMBL Database

# %%
# install libraries
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\cmkin\anaconda3\lib\site-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (2.26.0)
# Requirement already satisfied: requests-cache~=0.7.0 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: urllib3 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (1.26.7)
# Requirement already satisfied: easydict in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in c:\users\cmkin\anaconda3\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# Search for target protein

# %%
# test case: Polyketide synthase Pks13
target = new_client.target
target_query = target.search('Pks13')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []  Mycobacterium tuberculosis (strain ATCC 25618 ...
#
#                    pref_name  score  species_group_flag target_chembl_id  \
# 0  Polyketide synthase Pks13   28.0               False    CHEMBL4105939
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'I6X8D2', 'component_descriptio...  SINGLE PROTEIN   83332

# %% [markdown]
# # Select and retrieve bioactivity data

# %%
# select the target of interest from the search results
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4105939'

# %% [markdown]
# Filter results to retrieve only bioactivity data for protein of interest that are reported as IC50 values in nM units

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  \
# 0             None     18127365
# 1             None     19164286
# 2             None     22058278
#
#                                  activity_properties assay_chembl_id  \
# 0                                                 []   CHEMBL4028447
# 1                                                 []   CHEMBL4383981
# 2  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
#
#                                    assay_description assay_type  \
# 0  Inhibition of Mycobacterium tuberculosis ATCC ...          B
# 1  Inhibition of Mycobacterium tuberculosis H37Rv...          B
# 2  Mycobacterium tuberculosis Polyketide synthase...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000019
# 1                    None                   None  BAO_0000190  BAO_0000019
# 2                    None                   None  BAO_0000190  BAO_0000019
#
#    ...                                    target_organism  \
# 0  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 1  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 2  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
#
#             target_pref_name target_tax_id text_value  toid   type    units  \
# 0  Polyketide synthase Pks13         83332       None  None   IC50       uM
# 1  Polyketide synthase Pks13         83332       None  None   IC50  ug ml-1
# 2  Polyketide synthase Pks13         83332       None  None  pIC50     None
#
#      uo_units upper_value             value
# 0  UO_0000065        None              0.26
# 1  UO_0000274        None              0.19
# 2  UO_0000065        None  4.22002298548261
#
# [3 rows x 45 columns]

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# # Handling missing data

# %% [markdown]
# Exclude any compound that has missing value for the standard_value column

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  \
# 0               None     18127365
# 1               None     19164286
# 2               None     22058278
# 3               None     22058279
# 4               None     22058281
# ..               ...          ...
# 598             None     22068933
# 599             None     22068986
# 600             None     22068987
# 601             None     22068993
# 602             None     22068996
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []   CHEMBL4028447
# 1                                                   []   CHEMBL4383981
# 2    [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 3    [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 4    [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# ..                                                 ...             ...
# 598  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 599  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 600  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 601  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
# 602  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4649965
#
#                                      assay_description assay_type  \
# 0    Inhibition of Mycobacterium tuberculosis ATCC ...          B
# 1    Inhibition of Mycobacterium tuberculosis H37Rv...          B
# 2    Mycobacterium tuberculosis Polyketide synthase...          F
# 3    Mycobacterium tuberculosis Polyketide synthase...          F
# 4    Mycobacterium tuberculosis Polyketide synthase...          F
# ..                                                 ...        ...
# 598  Mycobacterium tuberculosis Polyketide synthase...          F
# 599  Mycobacterium tuberculosis Polyketide synthase...          F
# 600  Mycobacterium tuberculosis Polyketide synthase...          F
# 601  Mycobacterium tuberculosis Polyketide synthase...          F
# 602  Mycobacterium tuberculosis Polyketide synthase...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 598                    None                   None  BAO_0000190  BAO_0000019
# 599                    None                   None  BAO_0000190  BAO_0000019
# 600                    None                   None  BAO_0000190  BAO_0000019
# 601                    None                   None  BAO_0000190  BAO_0000019
# 602                    None                   None  BAO_0000190  BAO_0000019
#
#      ...                                    target_organism  \
# 0    ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 1    ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 2    ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 3    ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 4    ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# ..   ...                                                ...
# 598  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 599  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 600  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 601  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
# 602  ...  Mycobacterium tuberculosis (strain ATCC 25618 ...
#
#               target_pref_name target_tax_id text_value  toid   type    units  \
# 0    Polyketide synthase Pks13         83332       None  None   IC50       uM
# 1    Polyketide synthase Pks13         83332       None  None   IC50  ug ml-1
# 2    Polyketide synthase Pks13         83332       None  None  pIC50     None
# 3    Polyketide synthase Pks13         83332       None  None  pIC50     None
# 4    Polyketide synthase Pks13         83332       None  None  pIC50     None
# ..                         ...           ...        ...   ...    ...      ...
# 598  Polyketide synthase Pks13         83332       None  None  pIC50     None
# 599  Polyketide synthase Pks13         83332       None  None  pIC50     None
# 600  Polyketide synthase Pks13         83332       None  None  pIC50     None
# 601  Polyketide synthase Pks13         83332       None  None  pIC50     None
# 602  Polyketide synthase Pks13         83332       None  None  pIC50     None
#
#        uo_units upper_value             value
# 0    UO_0000065        None              0.26
# 1    UO_0000274        None              0.19
# 2    UO_0000065        None  4.22002298548261
# 3    UO_0000065        None  4.60248529399195
# 4    UO_0000065        None  4.14284041217382
# ..          ...         ...               ...
# 598  UO_0000065        None               4.0
# 599  UO_0000065        None  5.05674199241346
# 600  UO_0000065        None  4.89637185707977
# 601  UO_0000065        None  4.62596785534237
# 602  UO_0000065        None  4.72843604674767
#
# [603 rows x 45 columns]

# %% [markdown]
# # Data pre-processing of bioactivity data

# %% [markdown]
# The IC50 unit contains the bioactivity data. Compounds are classified accourding to the following parameters:
# - Active:   IC50 <= 1,000 nM
# - Inactive: IC50 >= 10,000 nM
# - Values in between 1,000 and 10,000 nM will be considered as intermediate.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Combine the three columns (molecule_chembl_id, anonical_smiles, standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4063356  CCOC(=O)c1c(-c2ccccc2)oc2ccc(O)c(CN3CCC(C)CC3)c12
# 1        CHEMBL4443524   CNC(=O)c1c(-c2ccc(O)cc2)oc2ccc(O)c(CN3CCCCC3)c12
# 2        CHEMBL3442631                     CNC(=O)c1cc2c(nc1NC(C)C)CCNCC2
# 3        CHEMBL3442631                     CNC(=O)c1cc2c(nc1NC(C)C)CCNCC2
# 4        CHEMBL3442632                    CNC(=O)c1cc2c(nc1NCC1CC1)CCNCC2
# ..                 ...                                                ...
# 598      CHEMBL3487994                 Cc1cnn(CC(C)NCC(=O)NCCOc2ccccc2)c1
# 599      CHEMBL3493579       Cc1nc(C)n(C2CCCN(C(=O)c3nc(C)n4ccccc34)C2)n1
# 600      CHEMBL3493579       Cc1nc(C)n(C2CCCN(C(=O)c3nc(C)n4ccccc34)C2)n1
# 601      CHEMBL3496335              COc1cc(/C=C/c2ncc(C(=O)O)s2)cc(Cl)c1O
# 602      CHEMBL3496335              COc1cc(/C=C/c2ncc(C(=O)O)s2)cc(Cl)c1O
#
#     standard_value
# 0            260.0
# 1             0.19
# 2         60252.77
# 3         24975.53
# 4         71971.34
# ..             ...
# 598       100000.0
# 599        8775.22
# 600       12694.87
# 601       23660.95
# 602       18688.05
#
# [603 rows x 3 columns]

# %%
# adds bioactivity class to the dataframe
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4063356  CCOC(=O)c1c(-c2ccccc2)oc2ccc(O)c(CN3CCC(C)CC3)c12
# 1        CHEMBL4443524   CNC(=O)c1c(-c2ccc(O)cc2)oc2ccc(O)c(CN3CCCCC3)c12
# 2        CHEMBL3442631                     CNC(=O)c1cc2c(nc1NC(C)C)CCNCC2
# 3        CHEMBL3442631                     CNC(=O)c1cc2c(nc1NC(C)C)CCNCC2
# 4        CHEMBL3442632                    CNC(=O)c1cc2c(nc1NCC1CC1)CCNCC2
# ..                 ...                                                ...
# 598      CHEMBL3487994                 Cc1cnn(CC(C)NCC(=O)NCCOc2ccccc2)c1
# 599      CHEMBL3493579       Cc1nc(C)n(C2CCCN(C(=O)c3nc(C)n4ccccc34)C2)n1
# 600      CHEMBL3493579       Cc1nc(C)n(C2CCCN(C(=O)c3nc(C)n4ccccc34)C2)n1
# 601      CHEMBL3496335              COc1cc(/C=C/c2ncc(C(=O)O)s2)cc(Cl)c1O
# 602      CHEMBL3496335              COc1cc(/C=C/c2ncc(C(=O)O)s2)cc(Cl)c1O
#
#     standard_value bioactivity_class
# 0            260.0            active
# 1             0.19            active
# 2         60252.77          inactive
# 3         24975.53          inactive
# 4         71971.34          inactive
# ..             ...               ...
# 598       100000.0          inactive
# 599        8775.22      intermediate
# 600       12694.87          inactive
# 601       23660.95          inactive
# 602       18688.05          inactive
#
# [603 rows x 4 columns]

# %%
# save dataframe to CSV file
df4.to_csv('bioactivity_preprocessed_data.csv', index=False)
