# %% [markdown]
# # Bioactivity data mining for drug discovery using ChEMBL

# %% [markdown]
# Install the ChEMBL web service package to retrieve bioactivity data from ChEMBL Database

# %%
# install libraries
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\cmkin\anaconda3\lib\site-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (2.26.0)
# Requirement already satisfied: easydict in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (1.26.7)
# Requirement already satisfied: requests-cache~=0.7.0 in c:\users\cmkin\anaconda3\lib\site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cmkin\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.2)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\users\cmkin\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: six in c:\users\cmkin\anaconda3\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# Search for target protein

# %%
# test case: EGFR
target = new_client.target
target_query = target.search('EGFR')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'Q01279', 'xref_name': None, 'xre...  Mus musculus
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3  [{'xref_id': 'P00533', 'xref_name': None, 'xre...  Homo sapiens
# 4                                                 []  Homo sapiens
# 5                                                 []  Homo sapiens
# 6                                                 []  Homo sapiens
# 7                                                 []  Homo sapiens
# 8                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0             Epidermal growth factor receptor erbB1   16.0
# 1                                        EGFR/PPP1CA   16.0
# 2                                           VHL/EGFR   16.0
# 3             Epidermal growth factor receptor erbB1   12.0
# 4  Protein cereblon/Epidermal growth factor receptor   11.0
# 5  MER intracellular domain/EGFR extracellular do...    9.0
# 6  Epidermal growth factor receptor and ErbB2 (HE...    7.0
# 7  Baculoviral IAP repeat-containing protein 2/Ep...    7.0
# 8                   Epidermal growth factor receptor    5.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL3608
# 1               False    CHEMBL4523747
# 2               False    CHEMBL4523998
# 3               False        CHEMBL203
# 4               False    CHEMBL4523680
# 5               False    CHEMBL3137284
# 6               False    CHEMBL2111431
# 7               False    CHEMBL4802031
# 8               False    CHEMBL2363049
#
#                                    target_components  \
# 0  [{'accession': 'Q01279', 'component_descriptio...
# 1  [{'accession': 'P00533', 'component_descriptio...
# 2  [{'accession': 'P00533', 'component_descriptio...
# 3  [{'accession': 'P00533', 'component_descriptio...
# 4  [{'accession': 'P00533', 'component_descriptio...
# 5  [{'accession': 'P00533', 'component_descriptio...
# 6  [{'accession': 'P04626', 'component_descriptio...
# 7  [{'accession': 'P00533', 'component_descriptio...
# 8  [{'accession': 'P04626', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3               SINGLE PROTEIN    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606
# 5             CHIMERIC PROTEIN    9606
# 6               PROTEIN FAMILY    9606
# 7  PROTEIN-PROTEIN INTERACTION    9606
# 8               PROTEIN FAMILY    9606

# %% [markdown]
# # Select and retrieve bioactivity data

# %%
# select the target of interest from the search results
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL203'

# %% [markdown]
# Filter results to retrieve only bioactivity data for protein of interest that are reported as IC50 values in nM units

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#       activity_comment  activity_id  \
# 0                 None        32260
# 1                 None        32263
# 2                 None        32265
# 3                 None        32267
# 4                 None        32270
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 1                                                     []    CHEMBL621151
# 2                                                     []    CHEMBL615325
# 3                                                     []    CHEMBL674637
# 4                                                     []    CHEMBL621151
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format  ... target_organism  \
# 0      BAO_0000357  ...    Homo sapiens
# 1      BAO_0000219  ...    Homo sapiens
# 2      BAO_0000219  ...    Homo sapiens
# 3      BAO_0000357  ...    Homo sapiens
# 4      BAO_0000219  ...    Homo sapiens
# ...            ...  ...             ...
# 15258  BAO_0000357  ...    Homo sapiens
# 15259  BAO_0000357  ...    Homo sapiens
# 15260  BAO_0000357  ...    Homo sapiens
# 15261  BAO_0000357  ...    Homo sapiens
# 15262  BAO_0000357  ...    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 1      Epidermal growth factor receptor erbB1          9606       None  None
# 2      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 4      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type  units    uo_units upper_value  value
# 0       IC50     uM  UO_0000065        None  0.041
# 1       IC50     uM  UO_0000065        None    0.3
# 2       IC50     uM  UO_0000065        None   7.82
# 3       IC50     uM  UO_0000065        None   0.17
# 4       IC50     uM  UO_0000065        None   0.04
# ...      ...    ...         ...         ...    ...
# 15258   IC50     µM        None        None   20.0
# 15259   IC50     µM        None        None   4.59
# 15260  pIC50   None        None        None    6.0
# 15261  pIC50   None        None        None    6.0
# 15262  pIC50   None        None        None    6.0
#
# [15263 rows x 45 columns]

# %%
df.to_csv('EGFR_01_bioactivity_data_raw.csv', index=False)

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#       activity_comment  activity_id  \
# 0                 None        32260
# 1                 None        32263
# 2                 None        32265
# 3                 None        32267
# 4                 None        32270
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 1                                                     []    CHEMBL621151
# 2                                                     []    CHEMBL615325
# 3                                                     []    CHEMBL674637
# 4                                                     []    CHEMBL621151
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format  ... target_organism  \
# 0      BAO_0000357  ...    Homo sapiens
# 1      BAO_0000219  ...    Homo sapiens
# 2      BAO_0000219  ...    Homo sapiens
# 3      BAO_0000357  ...    Homo sapiens
# 4      BAO_0000219  ...    Homo sapiens
# ...            ...  ...             ...
# 15258  BAO_0000357  ...    Homo sapiens
# 15259  BAO_0000357  ...    Homo sapiens
# 15260  BAO_0000357  ...    Homo sapiens
# 15261  BAO_0000357  ...    Homo sapiens
# 15262  BAO_0000357  ...    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 1      Epidermal growth factor receptor erbB1          9606       None  None
# 2      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 4      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type  units    uo_units upper_value  value
# 0       IC50     uM  UO_0000065        None  0.041
# 1       IC50     uM  UO_0000065        None    0.3
# 2       IC50     uM  UO_0000065        None   7.82
# 3       IC50     uM  UO_0000065        None   0.17
# 4       IC50     uM  UO_0000065        None   0.04
# ...      ...    ...         ...         ...    ...
# 15258   IC50     µM        None        None   20.0
# 15259   IC50     µM        None        None   4.59
# 15260  pIC50   None        None        None    6.0
# 15261  pIC50   None        None        None    6.0
# 15262  pIC50   None        None        None    6.0
#
# [15263 rows x 45 columns]

# %%
df.to_csv('EGFR_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# # Handling missing data

# %% [markdown]
# Exclude any compound that has missing value for the standard_value column

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# C:\Users\cmkin\AppData\Local\Temp/ipykernel_15272/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#       activity_comment  activity_id  \
# 0                 None        32260
# 1                 None        32263
# 2                 None        32265
# 3                 None        32267
# 4                 None        32270
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 1                                                     []    CHEMBL621151
# 2                                                     []    CHEMBL615325
# 3                                                     []    CHEMBL674637
# 4                                                     []    CHEMBL621151
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format  ... target_organism  \
# 0      BAO_0000357  ...    Homo sapiens
# 1      BAO_0000219  ...    Homo sapiens
# 2      BAO_0000219  ...    Homo sapiens
# 3      BAO_0000357  ...    Homo sapiens
# 4      BAO_0000219  ...    Homo sapiens
# ...            ...  ...             ...
# 15258  BAO_0000357  ...    Homo sapiens
# 15259  BAO_0000357  ...    Homo sapiens
# 15260  BAO_0000357  ...    Homo sapiens
# 15261  BAO_0000357  ...    Homo sapiens
# 15262  BAO_0000357  ...    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 1      Epidermal growth factor receptor erbB1          9606       None  None
# 2      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 4      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type  units    uo_units upper_value  value
# 0       IC50     uM  UO_0000065        None  0.041
# 1       IC50     uM  UO_0000065        None    0.3
# 2       IC50     uM  UO_0000065        None   7.82
# 3       IC50     uM  UO_0000065        None   0.17
# 4       IC50     uM  UO_0000065        None   0.04
# ...      ...    ...         ...         ...    ...
# 15258   IC50     µM        None        None   20.0
# 15259   IC50     µM        None        None   4.59
# 15260  pIC50   None        None        None    6.0
# 15261  pIC50   None        None        None    6.0
# 15262  pIC50   None        None        None    6.0
#
# [13897 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 8915

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#       activity_comment  activity_id  \
# 0                 None        32260
# 3                 None        32267
# 6                 None        32680
# 7                 None        32770
# 8                 None        32772
# ...                ...          ...
# 15258       Not Active     23070040
# 15259             None     23090818
# 15260             None     23116071
# 15261             None     23116480
# 15262             None     23116841
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 3                                                     []    CHEMBL674637
# 6                                                     []    CHEMBL677833
# 7                                                     []    CHEMBL674643
# 8                                                     []    CHEMBL674643
# ...                                                  ...             ...
# 15258  [{'comments': None, 'relation': None, 'result_...   CHEMBL4509084
# 15259                                                 []   CHEMBL4510669
# 15260  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512500
# 15261  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512213
# 15262  [{'comments': None, 'relation': None, 'result_...   CHEMBL4512787
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 6      In vitro inhibition of Epidermal growth factor...          B
# 7      Inhibitory concentration of EGF dependent auto...          B
# 8      Inhibitory concentration of EGF dependent auto...          B
# ...                                                  ...        ...
# 15258                       EGFR kinase inhibition assay          B
# 15259  Protein Tyrosine Kinase, EGF Receptor Eurofins...          B
# 15260          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15261          EGFR(EGFRMGB1) Takeda global kinase panel          B
# 15262          EGFR(EGFRMGB1) Takeda global kinase panel          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 6                        None                   None  BAO_0000190
# 7                        None                   None  BAO_0000190
# 8                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 15258                    None                   None  BAO_0000179
# 15259                    None                   None  BAO_0000179
# 15260                    None                   None  BAO_0000179
# 15261                    None                   None  BAO_0000179
# 15262                    None                   None  BAO_0000179
#
#         bao_format  ... target_organism  \
# 0      BAO_0000357  ...    Homo sapiens
# 3      BAO_0000357  ...    Homo sapiens
# 6      BAO_0000357  ...    Homo sapiens
# 7      BAO_0000357  ...    Homo sapiens
# 8      BAO_0000357  ...    Homo sapiens
# ...            ...  ...             ...
# 15258  BAO_0000357  ...    Homo sapiens
# 15259  BAO_0000357  ...    Homo sapiens
# 15260  BAO_0000357  ...    Homo sapiens
# 15261  BAO_0000357  ...    Homo sapiens
# 15262  BAO_0000357  ...    Homo sapiens
#
#                              target_pref_name target_tax_id text_value  toid  \
# 0      Epidermal growth factor receptor erbB1          9606       None  None
# 3      Epidermal growth factor receptor erbB1          9606       None  None
# 6      Epidermal growth factor receptor erbB1          9606       None  None
# 7      Epidermal growth factor receptor erbB1          9606       None  None
# 8      Epidermal growth factor receptor erbB1          9606       None  None
# ...                                       ...           ...        ...   ...
# 15258  Epidermal growth factor receptor erbB1          9606       None  None
# 15259  Epidermal growth factor receptor erbB1          9606       None  None
# 15260  Epidermal growth factor receptor erbB1          9606       None  None
# 15261  Epidermal growth factor receptor erbB1          9606       None  None
# 15262  Epidermal growth factor receptor erbB1          9606       None  None
#
#         type  units    uo_units upper_value   value
# 0       IC50     uM  UO_0000065        None   0.041
# 3       IC50     uM  UO_0000065        None    0.17
# 6       IC50     uM  UO_0000065        None     9.3
# 7       IC50     uM  UO_0000065        None   500.0
# 8       IC50     uM  UO_0000065        None  3000.0
# ...      ...    ...         ...         ...     ...
# 15258   IC50     µM        None        None    20.0
# 15259   IC50     µM        None        None    4.59
# 15260  pIC50   None        None        None     6.0
# 15261  pIC50   None        None        None     6.0
# 15262  pIC50   None        None        None     6.0
#
# [8915 rows x 45 columns]

# %% [markdown]
# # Data pre-processing of bioactivity data

# %% [markdown]
# Combine the three columns (molecule_chembl_id, anonical_smiles, standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 15258      CHEMBL4520788  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...
# 15259      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 15260      CHEMBL4088216  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 15261      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 15262      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#       standard_value
# 0               41.0
# 1              300.0
# 2             7820.0
# 3              170.0
# 4               40.0
# ...              ...
# 15258           20.0
# 15259           4.59
# 15260         1000.0
# 15261         1000.0
# 15262         1000.0
#
# [13897 rows x 3 columns]

# %%
# save dataframe to CSV file
df3.to_csv('EGFR_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# # Labeling compounds as active, inactive, or intermediate

# %% [markdown]
# The IC50 unit contains the bioactivity data. Compounds are classified accourding to the following parameters:
# - Active:   IC50 <= 1,000 nM
# - Inactive: IC50 >= 10,000 nM
# - Values in between 1,000 and 10,000 nM will be considered as intermediate.

# %%
df4 = pd.read_csv('EGFR_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
# adds bioactivity class to the dataframe
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 13892      CHEMBL4520788  CNCc1ccccc1-c1csc([C@H](C)Nc2nc(C)nc3cc(OC)c(O...
# 13893      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
# 13894      CHEMBL4088216  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 13895      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 13896      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#        standard_value         class
# 0               41.00        active
# 1              300.00        active
# 2             7820.00  intermediate
# 3              170.00        active
# 4               40.00        active
# ...               ...           ...
# 13892           20.00        active
# 13893            4.59        active
# 13894         1000.00        active
# 13895         1000.00        active
# 13896         1000.00        active
#
# [13897 rows x 4 columns]

# %%
# save dataframe to CSV file
df5.to_csv('EGFR_03_bioactivity_data_curated.csv', index=False)

# %%
! zip EGFR.zip *.csv
# Out:
# updating: EGFR_01_bioactivity_data_raw.csv (deflated 92%)
# updating: EGFR_02_bioactivity_data_preprocessed.csv (deflated 85%)
# updating: EGFR_03_bioactivity_data_curated.csv (deflated 86%)
# updating: Pks13_bioactivity_data_2class_pIC50.csv (deflated 80%)
# updating: Pks13_bioactivity_data_3class_pIC50_pubchem_fp.csv (deflated 95%)
# updating: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
# updating: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 82%)
# updating: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 83%)
# updating: acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv (deflated 78%)
# updating: acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv (deflated 78%)
# updating: bioactivity_data.csv (deflated 93%)
# updating: bioactivity_data_raw.csv (deflated 91%)
# updating: bioactivity_preprocessed_data.csv (deflated 85%)
# updating: descriptors_output.csv (deflated 95%)
# updating: mannwhitneyu_LogP.csv (deflated 9%)
# updating: mannwhitneyu_MW.csv (deflated 7%)
# updating: mannwhitneyu_NumHAcceptors.csv (deflated 10%)
# updating: mannwhitneyu_NumHDonors.csv (deflated 8%)
# updating: mannwhitneyu_pIC50.csv (deflated 11%)
